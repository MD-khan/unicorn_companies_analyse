# %%
import pandas as pd
import numbers as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
file_path = "../data/raw/Unicorn_Companies.csv"
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
df.shape
# Out:
# (1074, 10)

# %%
# Check for duplicates.
df.drop_duplicates()
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B      4/7/17          Artificial intelligence
# 1          SpaceX     $100B     12/1/12                            Other
# 2           SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3          Stripe      $95B     1/23/14                          Fintech
# 4          Klarna      $46B    12/12/11                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B     6/29/17  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B     4/18/17  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B      5/6/21                Consumer & retail
# 1072         Zopa       $1B    10/19/21                          Fintech
# 1073        Zwift       $1B     9/16/20  E-commerce & direct-to-consumer
#
#                City  Country/Region      Continent  Year Founded Funding  \
# ...

# %%
# Display the data types of the columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
# Sort `companies` and display the first 10 rows of the resulting DataFrame.
df_sorted = df.sort_values(by='Year Founded', ascending=True)
df_sorted.head(10)
# Out:
#                          Company Valuation Date Joined  \
# 189         Otto Bock HealthCare       $4B     6/24/17
# 373          Promasidor Holdings       $2B     11/8/16
# 699   Five Star Business Finance       $1B     3/26/21
# 840     Radius Payment Solutions       $1B    11/27/17
# 11                    Epic Games      $32B    10/26/18
# 377                    BGL Group       $2B    11/24/17
# 1043              Thirty Madison       $1B      6/2/21
# 118                   Vice Media       $6B      4/2/11
# 129        Howden Group Holdings       $5B     9/29/20
# 360                      Carzone       $2B      3/1/19
#
#                              Industry          City  Country/Region  \
# 189                            Health    Duderstadt         Germany
# 373                 Consumer & retail     Bryanston    South Africa
# 699                             Other       Chennai           India
# 840                           Fintech         Crewe  United Kingdom
# ...

# %%
# Display each unique year that occurs in the dataset
# along with the number of companies that were founded in each unique year.
df_yearly = df['Year Founded'].value_counts().sort_index()
print(df_yearly)
# Out:
# Year Founded
# 1919      1
# 1979      1
# 1984      1
# 1990      1
# 1991      1
# 1992      1
# 1993      1
# 1994      2
# 1995      2
# 1996      1
# 1997      1
# 1998      5
# 1999      8
# 2000     11
# 2001      9
# 2002      4
# 2003      8
# 2004      8
# 2005     14
# 2006     15
# 2007     24
# 2008     27
# 2009     34
# 2010     40
# 2011     82
# 2012     95
# 2013     87
# 2014    109
# 2015    155
# 2016    110
# 2017     74
# 2018     61
# 2019     45
# 2020     25
# 2021     11
# Name: count, dtype: int64

# %%
# Plot a histogram of the Year Founded feature.
### YOUR CODE HERE ###
plt.figure(figsize=(12,6))
plt.hist(df['Year Founded'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel("Year Founded")
plt.ylabel("Number of Unicorn Companies")
plt.title("Unicorn Companies by Year founded")

plt.show()

# %%
# Convert the `Date Joined` column to datetime.
# Update the column with the converted values.

### YOUR CODE HERE ###
df['Date Joined'] = pd.to_datetime(df['Date Joined'])



# Display the data types of the columns in `companies`
# to confirm that the update actually took place.

### YOUR CODE HERE ###
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB
# ...

# %%
# Obtain the names of the months when companies gained unicorn status.
# Use the result to create a `Month Joined` column.
df['Joined Month'] = df['Date Joined'].dt.month # Extract Month
df['Joined Year'] = df['Date Joined'].dt.year   # Extract Year

# %%
df['Joined Year'] = df['Date Joined'].dt.year   # Extract Year

# %%
# Determine how many years it took for companies to reach unicorn status.
# Use the result to create a `Years To Join` column.
df['Years To Join'] = df['Joined Year'] - df['Year Founded']
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Joined Month  \
# 0  Sequoia Capital China, SIG Asia Investments, S...             4
# ...

# %%
# Filter dataset by a year of your interest (in terms of when companies reached unicorn status).
# Save the resulting subset in a new variable. 
df_filtered = df[df['Joined Year'] == '2017']
df_filtered.head()
# Out:
# Empty DataFrame
# Columns: [Company, Valuation, Date Joined, Industry, City, Country/Region, Continent, Year Founded, Funding, Select Investors, Joined Month, Joined Year, Years To Join]
# Index: []
